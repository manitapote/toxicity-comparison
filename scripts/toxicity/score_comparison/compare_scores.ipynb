# %%
import pandas as pd

# %%
df_result_median_user = pd.read_pickle(
    './../data/results/overall_score_comparison.pkl.gz'
)

# %%
df_result_median_user.columns
# Out:
# Index(['component', 'score', 'median_coor_score', 'median_non_coor_score',
#        'KS test p-value', 'Man Whitney p-value'],
#       dtype='object')

# %% [markdown]
# #### **Min scores**

# %%
df_result_median_user['median_coor_score'].min()
# Out:
# np.float64(0.0064086914)

# %%
df_result_median_user['median_coor_score'].min()
# Out:
# np.float64(0.0064086914)

# %% [markdown]
# #### **Max scores**

# %%
df_result_median_user['median_coor_score'].max()
# Out:
# np.float64(0.28034934)

# %%
df_result_median_user['median_coor_score'].max()
# Out:
# np.float64(0.28034934)

# %%
df_result_median = pd.read_pickle(
    './../data/results/overall_score_comparison.pkl.gz'
)

# %%
df_result_median
# Out:
#     component            score  median_coor_score  median_non_coor_score  \
# 0           0           INSULT           0.063549               0.050278
# 1           0           THREAT           0.133469               0.111563
# 2           0         TOXICITY           0.244430               0.235957
# 3           0  SEVERE_TOXICITY           0.018385               0.012769
# 4           0        PROFANITY           0.078055               0.053937
# 5           0  IDENTITY_ATTACK           0.230874               0.216685
# 6           1           INSULT           0.043251               0.050278
# 7           1           THREAT           0.131614               0.111563
# 8           1         TOXICITY           0.235957               0.235957
# 9           1  SEVERE_TOXICITY           0.011368               0.012769
# 10          1        PROFANITY           0.048426               0.053937
# 11          1  IDENTITY_ATTACK           0.200884               0.216685
# ...

# %%
df_result_median['median_coor_score'].max()
# Out:
# np.float64(0.28034934)

# %%
df_result_median['median_coor_score'].min()
# Out:
# np.float64(0.0064086914)

# %%
for i, x in df_result_median.groupby('component'):
    print(x)
    print('\n ************* \n')
# Out:
#    component            score  median_coor_score  median_non_coor_score  \
# 0          0           INSULT           0.063549               0.050278
# 1          0           THREAT           0.133469               0.111563
# 2          0         TOXICITY           0.244430               0.235957
# 3          0  SEVERE_TOXICITY           0.018385               0.012769
# 4          0        PROFANITY           0.078055               0.053937
# 5          0  IDENTITY_ATTACK           0.230874               0.216685
#
#    KS test p-value  Man Whitney p-value
# 0    1.110859e-163         3.224688e-95
# 1    8.550013e-296         5.474079e-69
# 2    5.548870e-127         4.669873e-18
# 3     0.000000e+00         0.000000e+00
# 4     0.000000e+00        3.694807e-309
# 5    3.877194e-186         4.029058e-55
#
#  *************
#
#     component            score  median_coor_score  median_non_coor_score  \
# 6           1           INSULT           0.043251               0.050278
# ...

# %%
# (df_result_median_user
#  .sort_values(by=['median_coor_user_score'],
#               ascending=False
#              )
#  .groupby(['component'])
 
#  .first()
#  .reset_index()
# )

# %%
# (df_result_median_user.loc[df_result_median_user['Man Whitney p-value'] < 0.05]
#  .sort_values(by=['median_coor_user_score'],
#               ascending=False
#              )
#  .groupby(['component'])
 
#  .first()
#  .reset_index()
# )

# %%
for i, x in df_result_median_user.groupby('component'):
    print(x)
    print('\n ************* \n')
# Out:
#    component            score  median_coor_score  median_non_coor_score  \
# 0          0           INSULT           0.063549               0.050278
# 1          0           THREAT           0.133469               0.111563
# 2          0         TOXICITY           0.244430               0.235957
# 3          0  SEVERE_TOXICITY           0.018385               0.012769
# 4          0        PROFANITY           0.078055               0.053937
# 5          0  IDENTITY_ATTACK           0.230874               0.216685
#
#    KS test p-value  Man Whitney p-value
# 0    1.110859e-163         3.224688e-95
# 1    8.550013e-296         5.474079e-69
# 2    5.548870e-127         4.669873e-18
# 3     0.000000e+00         0.000000e+00
# 4     0.000000e+00        3.694807e-309
# 5    3.877194e-186         4.029058e-55
#
#  *************
#
#     component            score  median_coor_score  median_non_coor_score  \
# 6           1           INSULT           0.043251               0.050278
# ...
